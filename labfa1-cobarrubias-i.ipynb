# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
library("ggplot2")

# %% [markdown]
# 1) Create a histogram using the diamonds dataset.
# Start with the following example:
#
# ggplot(diamonds) + geom_histogram(aes(x = carat))
# Re-write this plot using the layer() function instead of geom_histogram(), as demonstrated in class.
# Hint: If you are unsure about default values (e.g., stat, position), inspect the plot object using p$layers.

# %%
ggplot(diamonds) + layer(
  geom = "bar", 
  stat = "bin", 
  position = "stack", 
  mapping = aes(x = carat)
)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %% [markdown]
# 2) Recall that a histogram is a plot that uses stat_bin rather than stat_identity.
# Modify your histogram from Question 1 so that it uses a different geom, such as geom_line() or geom_point(), while still relying on stat_bin.

# %%
ggplot(diamonds) + 
  geom_line(aes(x = carat), stat = "bin")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %% [markdown]
# 3) Using the histogram with bars from Question 1, add an aesthetic mapping based on one of the factor variables in the dataset (e.g., cut, color, or clarity).
# Apply this mapping to either the fill or color aesthetic.

# %%
ggplot(diamonds) + 
  geom_histogram(aes(x = carat, fill = cut))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %% [markdown]
# 4) What is the default position adjustment used in a histogram?
# Change the position adjustment in the histogram you created in Question 3 to a different option (hint: try "dodge"), and observe how the plot changes.

# %%
ggplot(diamonds) + 
  geom_histogram(aes(x = carat, fill = cut), position = "dodge")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %% [markdown]
# 5) In 3–5 sentences, reflect on this activity by answering the following:
#
# What did you learn about how histograms are constructed in ggplot2?
#
# Which part of the activity was most challenging, and why?
#
# How did changing the geom, aesthetic, or position affect your understanding of the data?

# %% [markdown]
# *Based on the activity, the construction of a histogram is adding incremental details. The most challenging part is setting up the parameters for ggplot. It causes some errors. The more details are added in the histogram (adding layers etc.) the better and clearer the story the numbers tell.*
